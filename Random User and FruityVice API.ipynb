# %%
# !pip install randomuser

# %%
from randomuser import RandomUser
import pandas as pd

# %%
r = RandomUser()

# %%
some_list = r.generate_users(10)
some_list

# %%
name = r.get_full_name()
name
# Out:
# 'Britney Chambers'

# %%
for user in some_list:
    print(user.get_full_name()," ", user.get_email())
# Out:
# Nolhan Caron   nolhan.caron@example.com
# Georgia Morris   georgia.morris@example.com
# Urbano Lima   urbano.lima@example.com
# Eilev Kvalvik   eilev.kvalvik@example.com
# Isaiah Gibson   isaiah.gibson@example.com
# Norman Meyer   norman.meyer@example.com
# Don Hamilton   don.hamilton@example.com
# Timothe Marchand   timothe.marchand@example.com
# Elen Souza   elen.souza@example.com
# Gabriel Gonzalez   gabriel.gonzalez@example.com

# %% [markdown]
# ## Exercise 1
# In this Exercise, generate photos of the random 10 users.

# %%
for photos in some_list:
    print(photos.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/0.jpg
# https://randomuser.me/api/portraits/women/70.jpg
# https://randomuser.me/api/portraits/men/73.jpg
# https://randomuser.me/api/portraits/men/3.jpg
# https://randomuser.me/api/portraits/men/89.jpg
# https://randomuser.me/api/portraits/men/64.jpg
# https://randomuser.me/api/portraits/men/69.jpg
# https://randomuser.me/api/portraits/men/57.jpg
# https://randomuser.me/api/portraits/women/4.jpg
# https://randomuser.me/api/portraits/men/70.jpg

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
print(photos.get_full_name())
# Out:
# Gabriel Gonzalez

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)   
get_users()
# Out:
#                     Name  Gender                 City               State  \
# 0    Lieselotte Lehmkuhl  female             Dormagen  Schleswig-Holstein
# 1            سورنا حیدری    male                 بابل         خراسان رضوی
# 2         Lewis Gonzales    male             Paterson              Alaska
# 3      Elizabeth Nichols  female          Southampton      West Yorkshire
# 4             امیر یاسمی    male               اردبیل             کردستان
# 5           Thomas Green    male         New Plymouth   Manawatu-Wanganui
# 6           Erin Mendoza  female            Castlebar            Limerick
# 7  Gerrit-Jan Van Iersel    male  's-Heer Arendskerke             Drenthe
# 8         Dario Monteiro    male     Francisco Morato             Roraima
# 9        Maja Kristensen  female            Hurup Thy             Danmark
#
#                               Email                       DOB  \
# 0   lieselotte.lehmkuhl@example.com  1980-06-23T16:58:57.434Z
# ...

# %%
def obj_user():
    seun = []
    for obj_user in RandomUser.generate_users(4):
         
         seun.append({"seun": obj_user.get_full_name()})
         return seun
         
        
        
         # print("name":seun.get_full_name())

    # return pd.DataFrame(obj_user)


obj_user()
# Out:
# [{'seun': 'Emre Yetkiner'}]

# %% [markdown]
# ## Example 2: Fruityvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json 
import pandas as pd

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %% [markdown]
# We will obtain the [fruityvice](https://www.fruityvice.com) API data using `requests.get("url")` function. The data is in a json format.

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
result = json.loads(data.text)

# %%
pd.DataFrame(result)
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df = pd.json_normalize(result)
df
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
cherry = df.loc[df['name'] == 'cherry']

# %%
# (cherry.iloc[0]['family']), (cherry.iloc[0]['genus'])

# %%
banna = df.loc[df['name'] == 'banana']
if not banna.empty:
    calories = banna.iloc[0]['nutritions.calories']
else:
    print("No matching rows found for 'banana'")

# banna.iloc[0]['nutritions.calories']
# Out:
# No matching rows found for 'banana'
